# %%
from pathlib import Path
import librosa
import numpy as np
from matplotlib import pyplot as plt

base = Path.cwd() 
test_file = base / "birdclef-2023/train_audio/abethr1/XC128013.ogg"
# SHow audio
from IPython.display import Audio, display
display(Audio(test_file))

# Show time domain
def display_wave(filename, ogg, sample_rate):
    int16 = (ogg * 32767).astype(np.int16)
    return int16, sample_rate


# Show frequency domain
def display_spectogram()
ogg, sample_rate = librosa.load(filename)



print(test_file)
wave_test, wave_test_sample_rate = ogg_to_wave(test_file)
time = np.arange(len(wave_test)) / wave_test_sample_rate
plt.plot(time, wave_test)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')

librosa.feature.melspectrogram(y=y, sr=sr)
# Out:
# /Users/sebastianmendoza/Downloads/SYDE 577/Final Project/final_proj/birdclef-2023/train_audio/abethr1/XC128013.ogg
#                 <audio  controls="controls" >
#                     <source src="data:audio/ogg;base64,..." type="audio/ogg" />
#                     Your browser does not support the audio element.
#                 </audio>
