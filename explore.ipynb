# %%
import pandas as pd
from pathlib import Path

base = Path.cwd() 

df = pd.read_csv("birdclef-2023/train_metadata.csv")
df.head() # Examine first few rows of metadata to understand its structure
# Out:
#   primary_label secondary_labels              type  latitude  longitude  \
# 0       abethr1               []          ['song']    4.3906    38.2788
# 1       abethr1               []          ['call']   -2.9524    38.2921
# 2       abethr1               []          ['song']   -2.9524    38.2921
# 3       abethr1               []          ['song']   -2.9524    38.2921
# 4       abethr1               []  ['call', 'song']   -2.9524    38.2921
#
#       scientific_name               common_name         author  \
# 0  Turdus tephronotus  African Bare-eyed Thrush  Rolf A. de By
# 1  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 2  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 3  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
# 4  Turdus tephronotus  African Bare-eyed Thrush  James Bradley
#
#                                              license  rating  \
# 0  Creative Commons Attribution-NonCommercial-Sha...     4.0
# ...

# %%
from eda import run_all_edas

from IPython.display import display

eda_tables = run_all_edas(df)
for name, table in eda_tables.items():
    print(f"=== {name} ===")
    display(table)
# Out:
# === basic_overview ===
#                     metric     value
# 0                     rows  16941.00
# 1                  columns     12.00
# 2                memory_mb     10.50
# 3    unique_primary_labels    264.00
# 4        unique_recordists   1082.00
# 5     geotagged_recordings  16714.00
# 6        percent_geotagged     98.66
# 7  duplicate_species_codes       NaN
# 8              rating_mean      3.73
# 9               rating_std      1.10
# === missingness ===
#               column  missing  missing_pct
# 0           latitude      227         1.34
# 1          longitude      227         1.34
# 2      primary_label        0         0.00
# 3   secondary_labels        0         0.00
# 4               type        0         0.00
# 5    scientific_name        0         0.00
# 6        common_name        0         0.00
# 7             author        0         0.00
# 8            license        0         0.00
# 9             rating        0         0.00
# ...

# %% [markdown]
# # Look at Top 10 Bird Counts

# %%
# Show relevant metadata rows for top 10 species in terms of primary label counts
top_10_species = df['primary_label'].value_counts().nlargest(10).index
for species in top_10_species:
    print(f"--- Metadata for species: {species} ---")
    display(df[df['primary_label'] == species].head())
# Out:
# --- Metadata for species: barswa ---
#     primary_label secondary_labels                                type  \
# 895        barswa               []             ['call', 'flight call']
# 896        barswa               []                            ['song']
# 897        barswa               []                            ['song']
# 898        barswa               []  ['call', 'female', 'male', 'song']
# 899        barswa               []                            ['song']
#
#      latitude  longitude  scientific_name   common_name            author  \
# 895   46.4605     6.3914  Hirundo rustica  Barn Swallow         Bram Piot
# 896   35.0307  -120.6205  Hirundo rustica  Barn Swallow  Thomas G. Graves
# 897   45.3675   -73.8566  Hirundo rustica  Barn Swallow   Patrick Turgeon
# 898   56.1559    47.4939  Hirundo rustica  Barn Swallow  Albert Lastukhin
# 899   55.9937    -3.5605  Hirundo rustica  Barn Swallow       Mike Nelson
#
# ...
