# %%
from pathlib import Path
import librosa
import pandas as pd

base = Path.cwd()

df = pd.read_csv("birdclef-2023/train_metadata.csv")
top_10_species = df['primary_label'].value_counts().nlargest(10).index

# %%
# Remove metadata records that aren't in the top 10 species by primary label counts
df = df[df['primary_label'].isin(top_10_species)]
df.reset_index(drop=True, inplace=True)

# Overwrite the original CSV with top-10 filtered data
df.to_csv("birdclef-2023/train_metadata.csv", index=False)

# %%
# Add duration column to metadata
def get_duration(file_path):
    y, sr = librosa.load(file_path, sr=None)
    return librosa.get_duration(y=y, sr=sr)

# Only calculate duration for samples that don't have it set
if 'duration' not in df.columns:
    df['duration'] = None

# Filter to only samples without duration
missing_duration = df['duration'].isna()
print(f"Calculating duration for {missing_duration.sum()} samples without duration...")

# Apply duration calculation only to samples missing duration
df.loc[missing_duration, 'duration'] = df.loc[missing_duration, 'filename'].apply(
    lambda x: get_duration(base / "birdclef-2023" / "train_audio" / x)
)

df.to_csv("birdclef-2023/train_metadata_with_duration.csv", index=False)
print(f"Updated CSV saved with {len(df)} total records")

# %%
# Remove duplicates based on duration, author, primary_label
df_with_duration = pd.read_csv("birdclef-2023/train_metadata_with_duration.csv")
df = df_with_duration

# See what would be removed
removed = df[df.duplicated(subset=['duration', 'author', 'primary_label'], keep=False)]
print(f"Found {len(removed)} duplicate records based on duration, author, and primary_label")
print(removed)

df = df.drop_duplicates(subset=['duration', 'author', 'primary_label'])
df.to_csv("birdclef-2023/train_metadata_deduped.csv", index=False)
print(f"Deduplicated CSV saved with {len(df)} total records")
# Out:
# Found 66 duplicate records based on duration, author, and primary_label
#      primary_label secondary_labels                               type  \
# 308         barswa               []  ['call', 'song', 'various calls']
# 309         barswa               []  ['call', 'song', 'various calls']
# 394         barswa               []                  ['adult', 'song']
# 395         barswa               []                  ['adult', 'song']
# 420         barswa               []                           ['call']
# ...            ...              ...                                ...
# 4020        wlwwar               []                           ['call']
# 4022        wlwwar               []                   ['male', 'song']
# 4040        wlwwar               []               ['call', 'juvenile']
# 4580        woosan               []                           ['song']
# 4606        woosan               []                           ['song']
#
#       latitude  longitude         scientific_name     common_name  \
# 308    58.7542    23.8439         Hirundo rustica    Barn Swallow
# 309    58.7542    23.8439         Hirundo rustica    Barn Swallow
# 394    52.8858    23.8293         Hirundo rustica    Barn Swallow
# 395    52.8858    23.8293         Hirundo rustica    Barn Swallow
# 420    51.3672     5.8406         Hirundo rustica    Barn Swallow
# ...        ...        ...                     ...             ...
# 4020   65.6651    21.7502  Phylloscopus trochilus  Willow Warbler
# 4022   38.4870    48.6389  Phylloscopus trochilus  Willow Warbler
# 4040   55.9809    47.3936  Phylloscopus trochilus  Willow Warbler
# 4580   65.9570    16.2078         Tringa glareola  Wood Sandpiper
# 4606   63.8313    20.2607         Tringa glareola  Wood Sandpiper
#
#                  author                                            license  \
# 308     Stanislas Wroza  Creative Commons Attribution-NonCommercial-Sha...
# 309     Stanislas Wroza  Creative Commons Attribution-NonCommercial-Sha...
# 394    Ireneusz Oleksik  Creative Commons Attribution-NonCommercial-Sha...
# 395    Ireneusz Oleksik  Creative Commons Attribution-NonCommercial-Sha...
# 420          Ad Hilders  Creative Commons Attribution-NonCommercial-Sha...
# ...                 ...                                                ...
# 4020  Nils-Olof Jerling  Creative Commons Attribution-NonCommercial-Sha...
# 4022   Albert Lastukhin  Creative Commons Attribution-NonCommercial-Sha...
# 4040   Albert Lastukhin  Creative Commons Attribution-NonCommercial-Sha...
# 4580       Lars Edenius  Creative Commons Attribution-NonCommercial-Sha...
# 4606       Lars Edenius  Creative Commons Attribution-NonCommercial-Sha...
#
#       rating                                url             filename  \
# 308      5.0  https://www.xeno-canto.org/575747  barswa/XC575747.ogg
# 309      0.0  https://www.xeno-canto.org/575749  barswa/XC575749.ogg
# 394      4.5  https://www.xeno-canto.org/664976  barswa/XC664976.ogg
# 395      4.5  https://www.xeno-canto.org/664977  barswa/XC664977.ogg
# 420      3.0       http://xeno-canto.org/671664  barswa/XC671664.ogg
# ...      ...                                ...                  ...
# 4020     2.5  https://www.xeno-canto.org/478767  wlwwar/XC478767.ogg
# 4022     2.0  https://www.xeno-canto.org/480516  wlwwar/XC480516.ogg
# 4040     3.0  https://www.xeno-canto.org/497895  wlwwar/XC497895.ogg
# 4580     5.0  https://www.xeno-canto.org/608282  woosan/XC608282.ogg
# 4606     5.0  https://www.xeno-canto.org/647845  woosan/XC647845.ogg
#
#        duration
# 308   36.120000
# 309   36.120000
# 394   64.704000
# 395   64.704000
# 420   10.109000
# ...         ...
# 4020  21.551031
# 4022  10.396750
# 4040  26.122438
# 4580  15.333000
# 4606  15.333000
#
# [66 rows x 13 columns]
# Deduplicated CSV saved with 4727 total records
