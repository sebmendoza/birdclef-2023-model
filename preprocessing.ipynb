# %%
from pathlib import Path
import librosa
import pandas as pd

base = Path.cwd()

df = pd.read_csv("birdclef-2023/train_metadata.csv")
top_10_species = df['primary_label'].value_counts().nlargest(10).index

# %%
# Remove metadata records that aren't in the top 10 species by primary label counts
df = df[df['primary_label'].isin(top_10_species)]
print(df.shape)
df.reset_index(drop=True, inplace=True)

# Overwrite the original CSV with top-10 filtered data
df.to_csv("birdclef-2023/train_metadata.csv", index=False)
# Out:
# (4761, 13)

# %%
# Add duration column to metadata
def get_duration(file_path):
    y, sr = librosa.load(file_path, sr=None)
    return librosa.get_duration(y=y, sr=sr)

# Only calculate duration for samples that don't have it set
if 'duration' not in df.columns:
    df['duration'] = None

# Filter to only samples without duration
missing_duration = df['duration'].isna()
print(f"Calculating duration for {missing_duration.sum()} samples without duration...")

# Apply duration calculation only to samples missing duration
df.loc[missing_duration, 'duration'] = df.loc[missing_duration, 'filename'].apply(
    lambda x: get_duration(base / "birdclef-2023" / "train_audio" / x)
)

df.to_csv("birdclef-2023/train_metadata_with_duration.csv", index=False)
print(f"Updated CSV saved with {len(df)} total records")
# Out:
# Calculating duration for 4761 samples without duration...
# Updated CSV saved with 4761 total records

# %%
# Remove duplicates based on duration, author, primary_label
df_with_duration = pd.read_csv("birdclef-2023/train_metadata_with_duration.csv")
df = df_with_duration

# See what would be removed
removed = df[df.duplicated(subset=['duration', 'author', 'primary_label'], keep=False)]
print(f"Found {len(removed)} duplicate records based on duration, author, and primary_label")
print(removed)

df = df.drop_duplicates(subset=['duration', 'author', 'primary_label'])
df.to_csv("birdclef-2023/train_metadata_deduped.csv", index=False)
print(f"Deduplicated CSV saved with {len(df)} total records")
# Out:
# Found 66 duplicate records based on duration, author, and primary_label
#      primary_label secondary_labels                               type  \
# 308         barswa               []  ['call', 'song', 'various calls']
# 309         barswa               []  ['call', 'song', 'various calls']
# 394         barswa               []                  ['adult', 'song']
# 395         barswa               []                  ['adult', 'song']
# 420         barswa               []                           ['call']
# ...            ...              ...                                ...
# 4020        wlwwar               []                           ['call']
# 4022        wlwwar               []                   ['male', 'song']
# 4040        wlwwar               []               ['call', 'juvenile']
# 4580        woosan               []                           ['song']
# 4606        woosan               []                           ['song']
#
#       latitude  longitude         scientific_name     common_name  \
# 308    58.7542    23.8439         Hirundo rustica    Barn Swallow
# 309    58.7542    23.8439         Hirundo rustica    Barn Swallow
# 394    52.8858    23.8293         Hirundo rustica    Barn Swallow
# 395    52.8858    23.8293         Hirundo rustica    Barn Swallow
# 420    51.3672     5.8406         Hirundo rustica    Barn Swallow
# ...        ...        ...                     ...             ...
# 4020   65.6651    21.7502  Phylloscopus trochilus  Willow Warbler
# 4022   38.4870    48.6389  Phylloscopus trochilus  Willow Warbler
# 4040   55.9809    47.3936  Phylloscopus trochilus  Willow Warbler
# 4580   65.9570    16.2078         Tringa glareola  Wood Sandpiper
# 4606   63.8313    20.2607         Tringa glareola  Wood Sandpiper
#
#                  author                                            license  \
# 308     Stanislas Wroza  Creative Commons Attribution-NonCommercial-Sha...
# 309     Stanislas Wroza  Creative Commons Attribution-NonCommercial-Sha...
# 394    Ireneusz Oleksik  Creative Commons Attribution-NonCommercial-Sha...
# 395    Ireneusz Oleksik  Creative Commons Attribution-NonCommercial-Sha...
# 420          Ad Hilders  Creative Commons Attribution-NonCommercial-Sha...
# ...                 ...                                                ...
# 4020  Nils-Olof Jerling  Creative Commons Attribution-NonCommercial-Sha...
# 4022   Albert Lastukhin  Creative Commons Attribution-NonCommercial-Sha...
# 4040   Albert Lastukhin  Creative Commons Attribution-NonCommercial-Sha...
# 4580       Lars Edenius  Creative Commons Attribution-NonCommercial-Sha...
# 4606       Lars Edenius  Creative Commons Attribution-NonCommercial-Sha...
#
#       rating                                url             filename  \
# 308      5.0  https://www.xeno-canto.org/575747  barswa/XC575747.ogg
# 309      0.0  https://www.xeno-canto.org/575749  barswa/XC575749.ogg
# 394      4.5  https://www.xeno-canto.org/664976  barswa/XC664976.ogg
# 395      4.5  https://www.xeno-canto.org/664977  barswa/XC664977.ogg
# 420      3.0       http://xeno-canto.org/671664  barswa/XC671664.ogg
# ...      ...                                ...                  ...
# 4020     2.5  https://www.xeno-canto.org/478767  wlwwar/XC478767.ogg
# 4022     2.0  https://www.xeno-canto.org/480516  wlwwar/XC480516.ogg
# 4040     3.0  https://www.xeno-canto.org/497895  wlwwar/XC497895.ogg
# 4580     5.0  https://www.xeno-canto.org/608282  woosan/XC608282.ogg
# 4606     5.0  https://www.xeno-canto.org/647845  woosan/XC647845.ogg
#
#        duration
# 308   36.120000
# 309   36.120000
# 394   64.704000
# 395   64.704000
# 420   10.109000
# ...         ...
# 4020  21.551031
# 4022  10.396750
# 4040  26.122438
# 4580  15.333000
# 4606  15.333000
#
# [66 rows x 13 columns]
# Deduplicated CSV saved with 4727 total records

# %% [markdown]
# # Data Cleaning

# %%
# Load the deduplicated dataset
df = pd.read_csv("birdclef-2023/train_metadata_deduped.csv")
print(f"Initial shape: {df.shape}")
print(f"Initial columns: {df.columns.tolist()}")
print("Unique values in 'type' column:")
unique_type_values = df['type'].unique()
print(unique_type_values)
# Out:
# Initial shape: (4727, 13)
# Initial columns: ['primary_label', 'secondary_labels', 'type', 'latitude', 'longitude', 'scientific_name', 'common_name', 'author', 'license', 'rating', 'url', 'filename', 'duration']
# Unique values in 'type' column:
# ["['call', 'flight call']" "['song']" "['call', 'female', 'male', 'song']"
#  "['call', 'song']" "['flight call']" "['alarm call']"
#  "['begging call', 'call', 'song']" "['call', 'juvenile']" "['call']"
#  "['Begging calls']" "['flight call', 'male']" "['call', 'male', 'song']"
#  "['flight call', 'male', 'song']" "['male', 'song']" "['call', 'male']"
#  "['call', 'female', 'male']" "['call', 'flight call', 'song']"
#  "['song in flight']" "['alarm call', 'flight call']"
#  "['juvenile', 'song']"
#  "['alarm call', 'begging call', 'call', 'juvenile']"
#  "['alarm call', 'call', 'male']"
#  "['call', 'juvenile', 'voice of fledglings']"
#  "['begging call', 'feeding sounds']" "['call,flight call,begging call']"
#  "['begging call', 'juvenile']" "['call', 'flight call', 'highway']"
#  "['begging call', 'call']"
#  "['Begging calls from 3 nestlings in nest.', 'begging call', 'call']"
#  "['flight call', 'song']"
#  "['call', 'female', 'flight call', 'male', 'song']"
#  "['call', 'flight call', 'juvenile']"
#  "['begging call', 'call', 'juvenile', 'wing beat']"
#  "['Adults feeding babies']" "['alarm call', 'begging call', 'call']"
#  "['flight call', 'nocturnal flight call']"
#  '[\'"tilit" call\', \'flight call\']'
#  "['begging call', 'call', 'juvenile']"
#  "['flight call', 'nocturnal  flight call']"
#  "['alarm call', 'call', 'flight call']" "['flight call', 'juvenile']"
#  "['juvenile']" "['adult', 'call']" "['adult', 'anxiety call', 'call']"
#  "['adult', 'song']" "['nocturnal flight call']"
#  "['adult', 'call', 'chamado de contato do bando', 'sex uncertain']"
#  "['adult', 'male', 'song']" "['adult', 'flight call']"
#  "['adult', 'call', 'juvenile', 'sex uncertain']"
#  "['call', 'life stage uncertain', 'sex uncertain']"
#  "['call', 'song', 'various calls']"
#  "['adult', 'call', 'human voices', 'sex uncertain']" "['Song']"
#  "['adult', 'call', 'flight call']"
#  "['call', 'juvenile', 'sex uncertain']" "['uncertain']"
#  "['adult', 'call', 'life stage uncertain', 'sex uncertain']"
#  "['adult', 'begging call', 'call', 'juvenile', 'sex uncertain']"
#  "['call', 'life stage uncertain', 'sex uncertain', 'song']"
#  "['adult', 'call', 'sex uncertain']"
#  "['adult', 'alarm call', 'call', 'flight call', 'male']"
#  "['flight call', 'life stage uncertain', 'sex uncertain']"
#  "['adult', 'call', 'female', 'flight call', 'male', 'song']"
#  "['adult', 'alarm call']" "['adult', 'call', 'song']"
#  "['call', 'sex uncertain', 'song']" "['male', 'subsong']"
#  "['adult', 'call', 'duet', 'female', 'male']"
#  "['adult', 'call', 'male', 'song', 'subsong']"
#  "['begging call', 'female', 'juvenile']"
#  "['adult', 'dawn song', 'sex uncertain']"
#  "['adult', 'flight call', 'juvenile']"
#  "['adult', 'call', 'juvenile', 'song']" "['alarm call', 'call', 'song']"
#  "['adult', 'female', 'flight call', 'male']"
#  "['call', 'flight call', 'life stage uncertain', 'sex uncertain']"
#  "['group song', 'song']"
#  "['adult', 'alarm call', 'female', 'flight call', 'juvenile', 'male', 'sex uncertain', 'song']"
#  "['adult', 'alarm call', 'female', 'flight call', 'juvenile', 'male', 'sex uncertain']"
#  "['alarm call', 'call', 'flight call', 'life stage uncertain', 'sex uncertain']"
#  "['life stage uncertain', 'nocturnal flight call', 'sex uncertain']"
#  "['flight call', 'wing sound']"
#  "['adult', 'call', 'juvenile', 'sex uncertain', 'song']"
#  "['adult', 'dawn song', 'male']" "['flight call', 'various calls']"
#  "['adult', 'sex uncertain', 'song']"
#  "['adult', 'alarm call', 'call', 'flight call', 'sex uncertain', 'song']"
#  "['alarm call', 'call', 'flight call', 'song']"
#  "['call', 'flight call', 'nocturnal flight call']"
#  "['adult', 'sex uncertain']" "['']" "['alarm call', 'call']"
#  "['begging call']" "['begging call', 'female', 'juvenile', 'male']"
#  "['excitemente call,call in flight']" "['call in flight,song flight']"
#  "['call in flight']"
#  "['Aggression between the juveniles', 'begging call', 'call']"
#  "['female', 'flight call', 'juvenile', 'male']"
#  "['begging call', 'call', 'female', 'flight call', 'male']"
#  "['alarm call', 'begging call', 'call', 'female', 'flight call', 'juvenile', 'male']"
#  "['alarm call', 'begging call', 'call', 'female', 'flight call', 'juvenile', 'male', 'song']"
#  "['call', 'juvenile', 'song']" "['female', 'male', 'song']"
#  "['flight calls', 'nest chatter']"
#  "['alarm call', 'call', 'calls from the nest', 'flight call', 'song']"
#  "['city sounds', 'flight call']"
#  "['begging call', 'call', 'calls from the nest', 'juvenile']"
#  "['begging call', 'flight call']"
#  "['call', 'female', 'flight call', 'juvenile', 'male']"
#  "['flight call', 'nocturnal flightcall']"
#  "['aberrant calls of a flock foraging in a pine tree']"
#  "['call', 'colony', 'flight call']"
#  "['call', 'nestlings calls in the nest']"
#  "['adult', 'flight call', 'sex uncertain']"
#  "['adult', 'begging call', 'call', 'hatchling or nestling']"
#  '[\'"tjirr"\', \'flight call\', \'trill\']'
#  "['begging call', 'call', 'flight call']"
#  "['adult', 'call', 'flight call', 'sex uncertain']"
#  "['adult', 'flight call', 'sex uncertain', 'song']"
#  "['call', 'flight call', 'life stage uncertain', 'sex uncertain', 'song']"
#  "['call', 'hatchling or nestling']"
#  "['call', 'hatchling or nestling', 'sex uncertain']"
#  "['adult', 'begging call', 'call', 'hatchling or nestling', 'song']"
#  "['adult', 'call', 'flight call', 'song']"
#  "['adult', 'begging call', 'call', 'flight call', 'hatchling or nestling', 'juvenile']"
#  "['flight call', 'juvenile', 'sex uncertain']"
#  "['adult', 'call', 'female', 'flight call', 'juvenile', 'male', 'song']"
#  "['adult', 'call', 'juvenile']"
#  "['adult', 'call', 'flight call', 'sex uncertain', 'song']"
#  "['alarm call', 'call', 'female', 'male', 'song']"
#  "['alarm call', 'flight call', 'life stage uncertain', 'sex uncertain']"
#  "['anthropogenic', 'call', 'flight call', 'wood pigeon']"
#  "['anthropogenic', 'flight call']"
#  "['adult', 'alarm call', 'begging call', 'hatchling or nestling']"
#  "['call', 'flight call', 'wing sound']"
#  "['call', 'flight call', 'various calls']"
#  "['alarm call', 'call', 'descending call', 'flight call']"
#  "['alarm call', 'flight call', 'series of calls']"
#  "['alarm call', 'nocturnal flight call']"
#  "['alarm call', 'flight call', 'male']" "['call', 'female', 'juvenile']"
#  "['call', 'female']" "['call', 'quiet dissatisfied']"
#  "['begging call', 'flight call', 'juvenile']"
#  "['alarm call', 'female', 'flight call']"
#  "['alarm call', 'female', 'juvenile']" "['alarm call', 'female']"
#  "['alarm call', 'female', 'juvenile', 'male']"
#  "['alarm call', 'alarm call-female']" "['', 'begging call', 'juvenile']"
#  "['female', 'flight call', 'male']"
#  "['Coppulation', 'begging call', 'female', 'male']"
#  "['Coppulation', 'female']" "['drumming', 'song']"
#  "['', 'begging call', 'flight call', 'juvenile', 'out of the nest']"
#  "['begging call', 'call', 'flight call', 'juvenile']"
#  "['alarm call', 'begging call', 'juvenile']"
#  "['alarm call', 'call', 'female', 'male']"
#  "['flight call', 'life stage uncertain']"
#  "['call', 'flight call', 'juvenile', 'sex uncertain']"
#  "['adult', 'alarm call', 'begging call', 'call', 'female']"
#  "['adult', 'female', 'flight call']"
#  "['call', 'flight call', 'short calls']"
#  "['begging call', 'hatchling or nestling', 'sex uncertain']"
#  "['alarm call', 'life stage uncertain', 'sex uncertain']"
#  "['begging call', 'call', 'flight call', 'juvenile', 'sex uncertain']"
#  "['begging call', 'juvenile', 'sex uncertain']"
#  "['alarm call', 'call', 'life stage uncertain', 'sex uncertain']"
#  "['adult', 'call', 'social call']"
#  "['adult', 'call', 'juvenile', 'social call']"
#  "['call', 'flight call', 'social call']"
#  "['call', 'female', 'flight call', 'male']"
#  "['call', 'duck call', 'flight call', 'modulated call']"
#  "['adult', 'begging call', 'call']"
#  "['flight call', 'life stage uncertain', 'sex unce', 'sex uncertain']"
#  "['adult', 'begging call', 'female']" "['flight call', 'sex uncertain']"
#  "['call', 'short calls']" "['flight call', 'short calls']"
#  "['adult', 'call', 'female', 'flight call', 'male']"
#  "['adult', 'call', 'social']" "['alarm call', 'modulated calls']"
#  "['alarm call', 'social calls', 'whistles']" "['$', 'call']"
#  "['adult', 'flight call', 'hatchling or nestling']" "['adult']"
#  "['aggressive call', 'flight call', 'sex uncertain']"
#  "['call', 'courtship/copulation calls (?)']" "['call', 'odd grunts']"
#  "['adult', 'alarm call', 'sex uncertain']" "['call', 'sex uncertain']"
#  "['life stage uncertain', 'sex uncertain']"
#  "['adult', 'alarm call', 'flight call']" "['sex uncertain']"
#  "['female', 'flight call', 'male', 'song']" "['alarm and flight call']"
#  "['call', 'short call']" "['flight call', 'thin call']"
#  "['call', 'voices']" "['call', 'flight call', 'migration', 'trekroep']"
#  "['Nocturnal flight call', 'flight call']"
#  "['flight call', 'nocturnal call']"
#  "['flight call', 'night flight call']" "['Nocturnal flight call']"
#  "['Single Note Calls']" "['call', 'nocturnal flight call']"
#  "['nocturnal flight call', 'sex uncertain']"
#  "['adult', 'call', 'flight call', 'nocturnal flight call', 'song']"
#  "['adult', 'nocturnal flight call', 'sex uncertain']"
#  "['nocturnal flight call', 'nocturnal flight call']"
#  "['Calling at sea', 'adult', 'call', 'feeding call', 'sex uncertain']"
#  "['begging call', 'life stage uncertain', 'nocturnal flight call', 'sex uncertain']"
#  "['flight call', 'nocturnal flight call', 'tew call']"
#  "['Anthropogenic background noise', 'nocturnal flight call']"
#  "['flight call', 'nocturnal flight call', 'short calls']"
#  "['bisyllabic call', 'flight call']"
#  "['chatter calls', 'nocturnal flight call']"
#  "['alarm call', 'long call']"
#  "['flight call', 'nocturnal flight call', 'sex uncertain']"
#  "['call', 'nocturnal call']" "['adult', 'nocturnal flight call']"
#  "['call', 'flight call', 'life stage uncertain', 'nocturnal flight call', 'sex uncertain']"
#  "['adult', 'call', 'duet', 'female', 'male', 'song']"
#  "['anthropogenic:: rain', 'nocturnal flight call']"
#  "['dawn song', 'life stage uncertain', 'male', 'song']"
#  "['adult', 'call', 'nocturnal flight call', 'sex uncertain']"
#  "['adult', 'duet', 'song']" "['call', 'flight call', 'sex uncertain']"
#  "['aggressive calls', 'call']"
#  "['adult', 'life stage uncertain', 'sex uncertain', 'song']"
#  "['flight call', 'life stage uncertain', 'nocturnal flight call', 'sex uncertain']"
#  "['call', 'long whistles']"
#  "['nocturnal flight call', 'single-note call']"
#  "['nocturnal flight call', 'two-note call']"
#  "['low call', 'nocturnal flight call']"
#  "['nocturnal flight call', 'weak call']" "['Some wind', 'call', 'male']"
#  "['alarm']" "['call', 'flight call', 'male']" "['call from wire']"
#  "['call-song']" "['flight call', 'migration call']"
#  "['call', 'calls at roost']"
#  "['flight call', 'migrating birds', 'short call']"
#  "['alarm call', 'call', 'flight call', 'various calls']"
#  "['flight call', 'migrating bird']" "['aberrant flight call', 'call']"
#  "['call', 'female', 'flight call']"
#  "['alarm call', 'flight call', 'nocturnal flight call', 'plik call']"
#  "['adult', 'flight call', 'male']" "['flight call', 'rolled calls']"
#  "['adult', 'call', 'flight call', 'male']" "['adult', 'call', 'female']"
#  "['adult', 'alarm call', 'call', 'male']"
#  "['flight call', 'metallic call', 'short call']"
#  "['flight call', 'only plik calls in migration']"
#  "['adult', 'call', 'male', 'song']" "['adult', 'call', 'male']"
#  "['adult', 'call', 'female', 'flight call']"
#  "['adult', 'call', 'male', 'subsong']" "['adult', 'male', 'subsong']"
#  "['alarm call', 'female', 'flight call', 'male']"
#  "['adult', 'alarm call', 'call', 'female', 'flight call']"
#  '[\'"S" call\', \'nocturnal flight call\']'
#  '[\'"tew" calls\', \'flight call\']'
#  "['Misleading rolled calls', 'flight call']"
#  "['adult', 'call', 'female', 'male']"
#  "['alarm call', 'call', 'female', 'flight call', 'male']"
#  "['begging call', 'call', 'female', 'flight call', 'juvenile', 'male', 'song']"
#  "['call', 'calls from a perch']" "['call', 'call from a perch']"
#  "['alarm call', 'call', 'various calls']"
#  "['alarm call', 'over the nest']"
#  "['alarm call', 'big colony with hundreds of birds', 'call', 'flight call']"
#  "['big colony with hundreds of birds', 'call', 'flight call']"
#  '[\'call\', \'flight call\', \'short "kup"\', \'various calls\']'
#  "['big flock', 'flight call']" "['call', 'female', 'juvenile', 'male']"
#  "['adult', 'female', 'male', 'song']"
#  "['adult', 'flight call', 'juvenile', 'sex uncertain']"
#  "['adult', 'call', 'flight call', 'juvenile']" "['female', 'male']"
#  "['adult', 'female', 'juvenile', 'male', 'nocturnal flight call']"
#  "['adult', 'alarm call', 'call', 'flight call', 'sex uncertain']"
#  "['flight call', 'short call']" "['excitement call']" "['call', 'group']"
#  "['copulation calls']" "['alarm call', 'on 6-7 sec.']"
#  "['call', 'drumming', 'flight call']" "['male']" "['hostile', 'male']"
#  "['aggression', 'flight call', 'male']" "['call', 'human voice', 'song']"
#  "['subsong']" "['alarm call', 'song']"
#  "['call', 'flight call', 'raspy call']"
#  "['alarm call', 'flight call', 'hoarse call']"
#  "['probably flight call', 'song']"
#  "['alarm call', 'female', 'male', 'song']" "['sex uncertain', 'song']"
#  "['adult', 'alarm call', 'call', 'male', 'song']"
#  "['adult', 'alarm call', 'call', 'female', 'flight call', 'wings']"
#  "['hissing']" "['wing beats']" "['call', 'raspy call', 'song']"
#  "['call', 'flight call', 'interaction calls']"
#  "['aggression call', 'call', 'female', 'male', 'song']"
#  "['adult', 'aggressive call', 'call', 'female', 'male', 'song']"
#  "['autumn call', 'flight call']"
#  "['adult', 'call', 'sex uncertain', 'song']"
#  "['Interaction call', 'call', 'flight call']"
#  "['male', 'nocturnal flight call', 'song']"
#  "['life stage uncertain', 'sex uncertain', 'song']"
#  "['begging call', 'hatchling or nestling']"
#  "['agonistic call', 'alarm call', 'bird chased by a Merlin', 'call', 'flight call']"
#  "['a very untypical song', 'probably throat defect']"
#  "['Rattle', 'call']" "['autumn subsong', 'male', 'song']"
#  "['alarm call', 'autumn subsong', 'call']"
#  "['autumn subsong', 'call', 'male']" "['autumn subsong', 'call']"
#  "['alarm call', 'female', 'male']" "['Subsong', 'song']" "['calm-call']"
#  "['full song']" "['life stage uncertain', 'male', 'song']"
#  "['shy song', 'song']" "['call', 'low calls', 'song']"
#  "['call', 'low calls', 'rattle', 'whistle']"
#  '[\'"tiouk"\', \'call\', \'low calls\']'
#  '[\'"tiouk"\', \'shy song\', \'song\', \'subsong\']'
#  "['dawn song', 'song']" "['call', 'song', 'subsong']"
#  "['adult', 'alarm call', 'call', 'sex uncertain']"
#  "['adult', 'duet', 'male', 'song']"
#  "['Mixed singer', 'aberrant song', 'song']" "['mixed singer', 'song']"
#  "['autumn', 'male', 'song']" "['female', 'song']"
#  "['siskin-like-call', 'song']" "['plastic song', 'song']"
#  "['Mixed singer (Willow Warbler / Chiffchaff); aberrant singer', 'song']"
#  "['fitis-chiffchaff', 'mixed song', 'song']" "['Song', 'call']"
#  "['call', 'high-pitched hissing', 'male', 'song']"
#  "['(sub)song', 'song']" "['agonistic call', 'call']"
#  "['abberant song', 'song']" "['aberrant song']"
#  "['Singing near a road', 'song']"
#  '[\'"huiit and sssshh call"\', \'call\']'
#  "['Caprimulgus?', 'mystery sound', 'song']"
#  "['Introduction of singing as Phylloscopus collybita', 'song']"
#  "['alarm call', 'begging call']" "['alarm call', 'juvenile', 'male']"
#  "['song', 'wings']" "['flight call', 'high whistle']"
#  "['alarm call', 'high whistle']" "['aberrant', 'song']"
#  "['Lockruf', 'call']" "['mimicry/imitation', 'song']"
#  "['life stage uncertain', 'sex uncertain', 'song', 'subsong']"
#  "['pre-song: imitation - Anthus cervinus - flight call', 'song']"
#  "['juvenile', 'subsong']" "['adult', 'male', 'sex uncertain', 'song']"
#  "['complex song', 'song']"
#  "['Bruit de fond et bruits parasites.', 'life stage uncertain', 'male', 'song']"
#  "['aberrant', 'adult', 'male', 'mimicry/imitation', 'song']"
#  "['aberrant', 'mimicry/imitation', 'song', 'song-switching']"
#  "['aberrant', 'mimicry/imitation', 'mixed singer', 'song']"
#  "['aberrant', 'mixed singer', 'song']"
#  "['begging call', 'call', 'juvenile', 'sex uncertain']"
#  "['autumn subsong', 'call', 'subsong']" "['song', 'subsong']"
#  "['all of a sudden frightened', 'flight call']"
#  "['call', 'quiet conversations in a large flock on the bank']"
#  "['call', 'juvenile', 'quiet conversations in a large flock on the bank']"
#  "['female', 'flight call']" "['alarm near young']"
#  "['flight calls of a flock']" "['alarm call', 'call from the ground']"
#  "['flight call', 'migration call', 'nocturnal flight call']"
#  "['bickering', 'call']"
#  "['alarm call', 'call', 'flight call', 'short call']"
#  "['alarm call', 'call', 'long trill']"
#  "['call', 'flight call', 'long trill']" "['call', 'soft call']"
#  "['intraspecific agressive call']" "['flight call', 'nocturnal']"
#  "['call', 'excitement call', 'song']"
#  "['adult', 'flight call', 'male', 'song']"
#  "['adult', 'alarm call', 'call', 'flight call']"
#  "['adult', 'flight call', 'song']" "['call', 'song? wingbeats?']"
#  "['nocturnal flight call', 'song']" "['Alarm call']"
#  "['adult', 'call', 'female', 'male', 'song']"
#  "['contact call', 'flight call']"
#  "['call', 'life stage uncertain', 'nocturnal flight call', 'sex uncertain']"
#  "['call', 'two-note call']" "['call', 'single-note call']"]

# %%
# Step 1: Inspect NaN values
print("=== Step 1: Inspecting NaN values ===")
print("NaN counts per column:")
print(df.isna().sum())
print(f"\nRows with NaN latitude: {df['latitude'].isna().sum()}")
print(f"Rows with NaN longitude: {df['longitude'].isna().sum()}")
print(f"Rows with both NaN: {df[['latitude', 'longitude']].isna().all(axis=1).sum()}")

# Option: Keep rows with NaN coordinates but flag them
# Alternatively, we could drop them with: df = df.dropna(subset=['latitude', 'longitude'])
# For now, we'll keep them and handle them in geocoding step
df['has_coordinates'] = df[['latitude', 'longitude']].notna().all(axis=1)
print(f"Rows with valid coordinates: {df['has_coordinates'].sum()}")
# Out:
# === Step 1: Inspecting NaN values ===
# NaN counts per column:
# primary_label        0
# secondary_labels     0
# type                 0
# latitude            63
# longitude           63
# scientific_name      0
# common_name          0
# author               0
# license              0
# rating               0
# url                  0
# filename             0
# duration             0
# dtype: int64
#
# Rows with NaN latitude: 63
# Rows with NaN longitude: 63
# Rows with both NaN: 63
# Rows with valid coordinates: 4664

# %%
# Step 2: Drop unused columns
print("=== Step 2: Dropping unused columns ===")
print(f"Columns before dropping: {df.columns.tolist()}")

# Drop columns not useful for analysis
columns_to_drop = ['secondary_labels', 'scientific_name', 'common_name', 'author', 'license', 'url']

# Only drop columns that actually exist in the dataframe
existing_columns_to_drop = [col for col in columns_to_drop if col in df.columns]
missing_columns = [col for col in columns_to_drop if col not in df.columns]

if missing_columns:
    print(f"Note: These columns were not found (may have been dropped already): {missing_columns}")

if existing_columns_to_drop:
    df = df.drop(columns=existing_columns_to_drop)
    print(f"Dropped columns: {existing_columns_to_drop}")
else:
    print("No columns to drop (all specified columns are already missing)")

print(f"Columns after dropping: {df.columns.tolist()}")
print(f"Shape after dropping: {df.shape}")
# Out:
# === Step 2: Dropping unused columns ===
# Columns before dropping: ['primary_label', 'secondary_labels', 'type', 'latitude', 'longitude', 'scientific_name', 'common_name', 'author', 'license', 'rating', 'url', 'filename', 'duration', 'has_coordinates']
# Dropped columns: ['secondary_labels', 'scientific_name', 'common_name', 'author', 'license', 'url']
# Columns after dropping: ['primary_label', 'type', 'latitude', 'longitude', 'rating', 'filename', 'duration', 'has_coordinates']
# Shape after dropping: (4727, 8)

# %%
# Step 3: Clean up the 'type' column
print("=== Step 3: Cleaning up 'type' column ===")
import ast

def simplify_type(type_str):
    """Summarize type to 'call', 'song', 'blank', or 'both'."""
    try:
        type_list = ast.literal_eval(type_str) if isinstance(type_str, str) else type_str
        if not isinstance(type_list, list):
            type_list = [type_list]
        
        # Filter out empty strings and non-call/song related terms
        # Remove lifestage and sex information
        lifestage_sex_terms = ['adult', 'juvenile', 'hatchling or nestling', 'life stage uncertain',
                              'male', 'female', 'sex uncertain', '']
        
        # Keep only call/song related terms
        relevant_terms = [t.lower().strip() for t in type_list 
                         if t and str(t).strip() and t.lower().strip() not in lifestage_sex_terms]
        
        if not relevant_terms:
            return 'blank'
        
        # Check for 'call' and 'song' in the terms
        has_call = any('call' in term for term in relevant_terms)
        has_song = any('song' in term for term in relevant_terms)
        
        if has_call and has_song:
            return 'both'
        elif has_call:
            return 'call'
        elif has_song:
            return 'song'
        else:
            # If neither call nor song, but has other terms, default to 'call'
            return 'call'
    except:
        return 'blank'

# Apply simplification
df['type'] = df['type'].apply(simplify_type)

print("Type column distribution after cleaning:")
print(df['type'].value_counts())
print(f"\nType column now has {df['type'].nunique()} unique values: {df['type'].unique()}")
# Out:
# === Step 3: Cleaning up 'type' column ===
# Type column distribution after cleaning:
# type
# call     2673
# song     1198
# blank     587
# both      269
# Name: count, dtype: int64
#
# Type column now has 4 unique values: ['call' 'song' 'both' 'blank']

# %%
# Step 4: Extract country and continent from lat/long using geopy
print("=== Step 4: Extracting country and continent from coordinates ===")
try:
    from geopy.geocoders import Nominatim
    from geopy.exc import GeocoderTimedOut, GeocoderServiceError
    import time
    
    # Initialize geocoder (using Nominatim, which is free but has rate limits)
    geolocator = Nominatim(user_agent="birdclef_geocoding")
    
    def get_country_continent(lat, lon, max_retries=3):
        """Get country and continent from coordinates using geopy."""
        if pd.isna(lat) or pd.isna(lon):
            return None, None
        
        for attempt in range(max_retries):
            try:
                # Reverse geocode
                location = geolocator.reverse((float(lat), float(lon)), timeout=10)
                
                if location and location.raw:
                    address = location.raw.get('address', {})
                    country = address.get('country', None)
                    
                    # Simple continent mapping (can be improved)
                    continent = None
                    if country:
                        # Basic continent mapping for common countries
                        # This is simplified - for production, use a proper mapping
                        country_lower = country.lower()
                        if any(c in country_lower for c in ['united states', 'canada', 'mexico', 'brazil', 'argentina']):
                            continent = 'Americas'
                        elif any(c in country_lower for c in ['united kingdom', 'france', 'germany', 'spain', 'italy', 'sweden', 'norway', 'finland', 'poland', 'russia']):
                            continent = 'Europe'
                        elif any(c in country_lower for c in ['china', 'japan', 'india', 'thailand', 'indonesia', 'australia']):
                            continent = 'Asia' if 'australia' not in country_lower else 'Oceania'
                        elif any(c in country_lower for c in ['south africa', 'kenya', 'ethiopia', 'egypt']):
                            continent = 'Africa'
                    
                    return country, continent
                return None, None
            except (GeocoderTimedOut, GeocoderServiceError) as e:
                if attempt < max_retries - 1:
                    time.sleep(1)  # Wait before retry
                    continue
                return None, None
            except Exception as e:
                return None, None
        
        return None, None
    
    print("Geocoding coordinates (this may take a while due to rate limits)...")
    print("Note: Nominatim has rate limits, so this may be slow for large datasets.")
    
    # Apply geocoding only to rows with valid coordinates
    valid_mask = df[['latitude', 'longitude']].notna().all(axis=1)
    valid_indices = df[valid_mask].index
    
    # Initialize columns
    df['country'] = None
    df['continent'] = None
    
    # Process in batches with delays to respect rate limits
    batch_size = 100
    for i in range(0, len(valid_indices), batch_size):
        batch_indices = valid_indices[i:i+batch_size]
        for idx in batch_indices:
            country, continent = get_country_continent(df.loc[idx, 'latitude'], df.loc[idx, 'longitude'])
            df.at[idx, 'country'] = country
            df.at[idx, 'continent'] = continent
        
        if i + batch_size < len(valid_indices):
            time.sleep(1)  # Rate limiting delay
        
        if (i // batch_size + 1) % 10 == 0:
            print(f"Processed {min(i + batch_size, len(valid_indices))} / {len(valid_indices)} records...")
    
    print(f"\nSuccessfully geocoded {df['country'].notna().sum()} records")
    print(f"\nCountry distribution (top 10):")
    print(df['country'].value_counts().head(10))
    print(f"\nContinent distribution:")
    print(df['continent'].value_counts())
    
except ImportError:
    print("=== Geopy not available ===")
    print("To extract country/continent, install: pip install geopy")
    print("\nSkipping geocoding for now...")
    df['country'] = None
    df['continent'] = None
# Out:
# === Step 4: Extracting country and continent from coordinates ===
# Geocoding coordinates (this may take a while due to rate limits)...
# Note: Nominatim has rate limits, so this may be slow for large datasets.
# Processed 1000 / 4664 records...
# Processed 2000 / 4664 records...
# Processed 3000 / 4664 records...
# Processed 4000 / 4664 records...
#
# Successfully geocoded 4662 records
#
# Country distribution (top 10):
# country
# France             585
# España             541
# Polska             397
# Россия             369
# Deutschland        335
# Sverige            312
# United Kingdom     292
# Portugal           195
# Nederland          153
# Suomi / Finland    131
# Name: count, dtype: int64
#
# Continent distribution:
# continent
# Europe      1008
# Africa        82
# Americas      46
# Asia          29
# Name: count, dtype: int64

# %%
# Step 5: Final summary and save cleaned dataset
print("=== Step 5: Final summary ===")
print(f"Final shape: {df.shape}")
print(f"Final columns: {df.columns.tolist()}")
print(f"\nNaN counts in final dataset:")
print(df.isna().sum())
print(f"\nReduced dimensionality by dropping unused columns (secondary_labels, scientific_name, common_name, author, license, url)")
print(f"This helps reduce the curse of dimensionality!")

# Save cleaned dataset
output_file = "birdclef-2023/train_metadata_cleaned.csv"
df.to_csv(output_file, index=False)
print(f"\nCleaned dataset saved to: {output_file}")
print(f"Total records: {len(df)}")
# Out:
# === Step 5: Final summary ===
# Final shape: (4727, 10)
# Final columns: ['primary_label', 'type', 'latitude', 'longitude', 'rating', 'filename', 'duration', 'has_coordinates', 'country', 'continent']
#
# NaN counts in final dataset:
# primary_label         0
# type                  0
# latitude             63
# longitude            63
# rating                0
# filename              0
# duration              0
# has_coordinates       0
# country              65
# continent          3562
# dtype: int64
#
# Reduced dimensionality by dropping unused columns (secondary_labels, scientific_name, common_name, author, license, url)
# This helps reduce the curse of dimensionality!
#
# Cleaned dataset saved to: birdclef-2023/train_metadata_cleaned.csv
# Total records: 4727
