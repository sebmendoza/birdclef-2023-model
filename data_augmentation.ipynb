# %% [markdown]
# - Set flags to True/False to include augmentations in output

# %%
from data_augmentation import AudioAugmenter

# Create augmenter with desired augmentations
augmenter = AudioAugmenter(
    mixup=True,
    background_noise=True,
    pitch_shift=True,
    time_shift=True,
    freq_masking=True,
    time_masking=True,
    color_jitter=True,
    random_clip=True
)

# Example 1: Process all files (original behavior)
# augmented_data = augmenter.process_directory("birdclef-2023/train_audio")

# Example 2: Process specific species only
# augmented_data = augmenter.process_directory(
#     "birdclef-2023/train_audio",
#     species_filter=['barswa', 'comsan', 'hoopoe']
# )

# Example 3: Limit files per species for faster testing
# augmented_data = augmenter.process_directory(
#     "birdclef-2023/train_audio",
#     max_files_per_species=5
# )

# Example 4: Combine species filter with file limit
augmented_data = augmenter.process_directory(
    "birdclef-2023/train_audio",
    metadata_csv="birdclef-2023/train_metadata.csv",
    species_filter=['barswa', 'comsan', 'hoopoe'],
    max_files_per_species=3
)
# Out:
# 📊 Loading original metadata from birdclef-2023/train_metadata.csv
# 📊 Loaded metadata for 4761 original files
# Processing audio files from birdclef-2023/train_audio
# Species filter: ['barswa', 'comsan', 'hoopoe']
# Max files per species: 3
# Enabled augmentations: ['mixup', 'background_noise', 'pitch_shift', 'time_shift', 'freq_masking', 'time_masking', 'color_jitter', 'random_clip']
#
# 📁 Processing barswa...
#   Limited to 3 files (out of 500 available)
# 📊 Loaded metadata for 4761 original files
# Processing audio files from birdclef-2023/train_audio
# Species filter: ['barswa', 'comsan', 'hoopoe']
# Max files per species: 3
# Enabled augmentations: ['mixup', 'background_noise', 'pitch_shift', 'time_shift', 'freq_masking', 'time_masking', 'color_jitter', 'random_clip']
#
# 📁 Processing barswa...
#   Limited to 3 files (out of 500 available)
# Processed 3 files for barswa
#
# 📁 Processing comsan...
#   Limited to 3 files (out of 500 available)
# Processed 3 files for barswa
#
# 📁 Processing comsan...
#   Limited to 3 files (out of 500 available)
# Processed 3 files for comsan
#
# 📁 Processing hoopoe...
#   Limited to 3 files (out of 436 available)
# Processed 3 files for comsan
#
# 📁 Processing hoopoe...
#   Limited to 3 files (out of 436 available)
# Processed 3 files for hoopoe
#
# 🎛️ Generating mixup samples...
# Processed 3 files for hoopoe
#
# 🎛️ Generating mixup samples...
# Generated 100 mixup samples
#
# Generated 163 augmented samples
# Metadata saved to: birdclef-2023/augmented/augmented_metadata.csv
# Generated 100 mixup samples
#
# Generated 163 augmented samples
# Metadata saved to: birdclef-2023/augmented/augmented_metadata.csv
