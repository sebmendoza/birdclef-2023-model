# %%
from data_augmentation import AudioAugmenter

# Create memory-safe augmenter
augmenter = AudioAugmenter(
    # Enable fewer augmentations initially
    mixup=True,  # Disable mixup first (memory intensive)
    background_noise=True,
    pitch_shift=True,
    time_shift=False,
    freq_masking=True,
    time_masking=True,
    color_jitter=False,
)

# Example 1: Process all files (original behavior)
# augmented_data = augmenter.process_directory("birdclef-2023/train_audio")

# Example 2: Process specific species only
# augmented_data = augmenter.process_directory(
#     "birdclef-2023/train_audio",
#     species_filter=['barswa', 'comsan', 'hoopoe']
# )

# Example 3: Limit files per species for faster testing
# augmented_data = augmenter.process_directory(
#     "birdclef-2023/train_audio",
#     max_files_per_species=5
# )

test_data = augmenter.process_directory(
    "birdclef-2023/15secondchunks",
    species_filter=['barswa', 'comsan', 'combuz1'],
    max_files_per_species=5
)

# Regenerate metadata with proper inheritance
import regenerate_metadata_clean
regenerate_metadata_clean.regenerate_augmented_metadata()
# Out:
# Processing audio files from birdclef-2023/15secondchunks
# Species filter: ['barswa', 'comsan', 'combuz1']
# Max files per species: 5
# Enabled augmentations: ['mixup', 'background_noise', 'pitch_shift', 'freq_masking', 'time_masking']
#
# 📁 Processing combuz1...
#   Limited to 5 files (out of 475 available)
# Processed 5 files for combuz1
#
# 📁 Processing barswa...
#   Limited to 5 files (out of 494 available)
# Processed 5 files for barswa
#
# 📁 Processing comsan...
#   Limited to 5 files (out of 497 available)
# Processed 5 files for comsan
#
# 🎛️ Generating mixup samples...
# Generated 100 mixup samples
#
# Generated 175 augmented samples
# Metadata saved to: birdclef-2023/augmented/augmented_metadata.csv
# 🔄 Updating augmented metadata with proper inheritance...
# 📊 Loading original metadata from birdclef-2023/train_metadata_cleaned.csv
# 📊 Loading augmented metadata from birdclef-2023/augmented/augmented_metadata.csv
#    Original records: 4727
#    Augmented records: 175
# ...
